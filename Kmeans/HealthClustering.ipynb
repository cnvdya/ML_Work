# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans


df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    Gender  Height  Weight  Category
# 0    Male     174      96         4
# 1    Male     189      87         2
# 2  Female     185     110         4
# 3  Female     195     104         3
# 4    Male     149      61         3

# %%
df.describe(include='all')
# Out:
#         Gender      Height      Weight    Category
# count      500  500.000000  500.000000  500.000000
# unique       2         NaN         NaN         NaN
# top     Female         NaN         NaN         NaN
# freq       255         NaN         NaN         NaN
# mean       NaN  169.944000  106.000000    3.748000
# std        NaN   16.375261   32.382607    1.355053
# min        NaN  140.000000   50.000000    0.000000
# 25%        NaN  156.000000   80.000000    3.000000
# 50%        NaN  170.500000  106.000000    4.000000
# 75%        NaN  184.000000  136.000000    5.000000
# max        NaN  199.000000  160.000000    5.000000

# %%
demographic_attributes = ['Gender', 'Category']

df = df.drop(demographic_attributes, axis = 'columns')

df.head()
# Out:
#    Height  Weight
# 0     174      96
# 1     189      87
# 2     185     110
# 3     195     104
# 4     149      61

# %%
fig = plt.figure(figsize=(8,8))
plt.scatter(df['Height'], df['Weight'], c='black')
plt.show()

# %%
kmeans = KMeans(n_clusters=3).fit(df)

# %%
labels = kmeans.predict(df)
centroids = kmeans.cluster_centers_

# %%
fig = plt.figure(figsize=(8,8))

colmap = {1:'r', 2:'g', 3:'b'}
colors = map(lambda x: colmap[x+1], labels)
colors1 = list(colors)
plt.scatter(df['Height'], df['Weight'], color=colors1, alpha=0.5, edgecolor='k')
plt.xlabel('Height(meters)')
plt.ylabel('Weight(kgs)')
for idx, centroid in enumerate(centroids):
    plt.scatter(*centroid, color=colmap[idx+1])
plt.show()
